# %% [markdown]
# # **Start**

# %% [markdown]
# ## 🟡 Extra Installations

# %%
# --- Extra Installations ---

# %%
# Run this code --> then restart the kernel -->  run the code blocks required(dont run this again after running once)

# !pip install accelerate -U
# !pip install transformers[torch]
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.6/297.6 kB 6.3 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %%
# !pip install rouge-score
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24933 sha256=835a47e731dba4a218bb34896cba6ba7751a6837ca66d16d18c4ac60e9f132da
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge-score
# ...

# %%
# !pip install bert-score
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 1.8 MB/s eta 0:00:00
# ...

# %%
# !pip install emoji
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 433.8/433.8 kB 5.9 MB/s eta 0:00:00
# ...

# %%
# !pip install indic-num2words

# %% [markdown]
# ## 🟡 Helper Functions

# %%
# !pip install gdown

# %%
from rouge_score import rouge_scorer

# %% [markdown]
# ### ⚪ Delete File or Folder

# %%
import os
import shutil

def delete_file_or_folder(path):
    """
    Function to delete a file or folder.

    Parameters:
    - path (str): The path to the file or folder to be deleted.

    Returns:
    - None
    """
    try:
        # Check if the path exists
        if os.path.exists(path):
            # Check if the path is a file
            if os.path.isfile(path):
                # If it's a file, remove it using os.unlink
                os.unlink(path)
                print(f"File '{path}' has been deleted.")
            # Check if the path is a directory
            elif os.path.isdir(path):
                # If it's a directory, remove it using shutil.rmtree
                shutil.rmtree(path)
                print(f"Directory '{path}' has been deleted.")
        else:
            print(f"Path '{path}' does not exist.")
    except Exception as e:
        # Handle any exceptions that might occur during deletion
        print(f"Error occurred while deleting '{path}': {str(e)}")

# Specify the path to the file or folder to delete
file_or_folder_path = "/content/sample_data"
# Call the function to delete the file or folder
delete_file_or_folder(file_or_folder_path)
# Out:
# Directory '/content/sample_data' has been deleted.

# %% [markdown]
# ### ⚪ Command to Download Dataset

# %%
# !gdown --folder https://drive.google.com/drive/folders/14zdqk6vMEb1ixZor3XbMwkujQlivnQgC?usp=drive_link -O Dataset
# Out:
# Retrieving folder contents
# Processing file 1b2iZtrcCy18oPj1o5EsUxwgFDC4Rr0QR hindi_train.csv
# Processing file 1fQufzDH1IeR3a7Tjmf4ztg6GmteEreN5 HindiNews_test.csv
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From (original): https://drive.google.com/uc?id=1b2iZtrcCy18oPj1o5EsUxwgFDC4Rr0QR
# From (redirected): https://drive.google.com/uc?id=1b2iZtrcCy18oPj1o5EsUxwgFDC4Rr0QR&confirm=t&uuid=7774a01f-fc20-4c9d-b40e-2acfce359fbb
# To: /content/Dataset/hindi_train.csv
# 100% 162M/162M [00:01<00:00, 123MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1fQufzDH1IeR3a7Tjmf4ztg6GmteEreN5
# To: /content/Dataset/HindiNews_test.csv
# 100% 25.7M/25.7M [00:00<00:00, 97.3MB/s]
# Download completed

# %% [markdown]
# ### ⚪ Function to Print Folder Structure

# %%
import os

def print_folder_structure(folder_path, indent=""):
    """
    Recursively print the structure of a folder.

    Parameters:
    - folder_path (str): The path to the folder whose structure is to be printed.
    - indent (str): The indentation string for visualizing the hierarchy.

    Returns:
    - None
    """
    # Print the current directory name
    print(indent + os.path.basename(folder_path) + "/")

    # Iterate over the contents of the folder
    for item in os.listdir(folder_path):
        item_path = os.path.join(folder_path, item)
        # If the item is a directory, recursively call the function
        if os.path.isdir(item_path):
            print_folder_structure(item_path, indent + "    ")
        else:
            # If the item is a file, print its name
            print(indent + "    " + item)

# Example usage:
folder_path = "/kaggle/working"
print("Folder Structure:")
print_folder_structure(folder_path)
# Out:
# Folder Structure:
# working/
#     Dataset/
#         hindi_train.csv
#         HindiNews_test.csv
#     .virtual_documents/

# %% [markdown]
# ## 🟡 Data Analysis

# %%
import pandas as pd
# Load the dataset
# train_df = pd.read_csv("/kaggle/working/Dataset/hindi_train.csv")

#2023 training dataset

train_df = pd.read_csv("/content/Dataset/hindi_train.csv")

# test_df = pd.read_csv("/kaggle/input/hindi-test/test.csv")
# test_df = pd.read_csv("/content/Dataset/HindiNews_test.csv")

#2022 testing dataset

test_df = pd.read_csv("/content/test.csv")


train_df_subset = train_df.head(8000)
train_df = train_df_subset

test_df_subset=test_df.head(2000)
test_df= test_df_subset

# %%
from IPython.display import display
# Display the first few rows of the training dataset
print("Training Dataset (Number of samples: {})".format(train_df.shape[0]))
# Remove the 'Id' column from the training dataset
train_df.drop(columns=['Id'], inplace=True)
display(train_df.head())

# Display the first few rows of the test dataset
print("\nTest Dataset (Number of samples: {})".format(test_df.shape[0]))
# Remove the 'id' column from the test dataset
test_df.drop(columns=['id'], inplace=True)
display(test_df.head())
# Out:
# Training Dataset (Number of samples: 8000)
# <ipython-input-9-c21b0f7ccfc3>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df.drop(columns=['Id'], inplace=True)
#                                              Heading  \
# 0  गला दबाकर हत्या की; बॉडी बोरे में भरी, लोकल मा...
# 1  तेलंगाना में 18 की जान गई; जम्मू-कश्मीर में बा...
# 2  राजस्थान सरकार बनाएगी कर्ज राहत आयोग, कोर्ट के...
# 3  3 से 7 अगस्त तक कर सकेंगे अप्लाय, प्राइस बैंड ...
# 4  डाइनिंग टेबल पर कुकर-कड़ाही न सजाएं, चीन के खा...
#
#                                              Summary  \
# 0  Kerala Minor Girl Rape Case - केरल के एर्नाकुल...
# 1  इस साल मानसून सीजन में कई राज्यों में भारी तबा...
# 2  चुनावी साल में राजस्थान सरकार किसानों को लुभान...
# 3  Non-banking lender SBFC Finance's initial publ...
# ...

# %%
from num_to_words import num_to_word
# Convert numbers to words in Hindi
print(num_to_word(545589, lang='hi')) # पाँच लाख, पैंतालीस हज़ार, पाँच सौ, नवासी
# Out:
# पाँच लाख, पैंतालीस हज़ार, पाँच सौ, नवासी

# %%
import re
import emoji
from num_to_words import num_to_word
def preprocess_text(text):
    """
    Preprocess the given text.

    Parameters:
    - text (str): The text to be preprocessed

    Returns:
    - str: Preprocessed text.
    """
    # Convert emojis to textual representations and remove emoji placeholders
    text = re.sub(r':[a-zA-Z_]+:', ' ', emoji.demojize(str(text)))
    # Remove newline, carriage return, and tab characters, underscores, hyphens, tildes, plus signs, periods, special characters,
    text = re.sub(r'[\n\r\t_\-~\+\.\s]{2,}|[<>()|&©@#ø\[\]\'\",;:.।‘’]', ' ', str(text).replace('\u200d', '').lower())
    # text = re.sub("([a-zA-Z])",' ',str(text)).lower() # (*Note : currently removing english or we can convert it to hindi using API*) --- For English Removal
    text = re.sub("(\s+)",' ',str(text)).lower() # remove multiple spaces.
    # Convert numeric values to their word representation
    text = re.sub(r'\b(\d+)\b', lambda x: num_to_word(int(x.group(0)), lang='hi'), text)
    text = re.sub(r'[\n\r\t_\-~\+\.\s]{2,}|[<>()|&©@#ø\[\]\'\",;:.।‘’]', ' ', str(text).replace('\u200d', '').lower())
    return text.strip()

# Example usage:
text_to_preprocess = "\t(सांसदी)__ ++++ \n\nhello Kerala...      \tGirl  Case - केरल के एर्नाकुल...जाने के बाद 🎉अप्रैल ||| में सरकारी9 बंगला 44 🏠छोड़...😊"
text_to_preprocess =  "नोकिया C12 प्लस में 6.3 इंच HD प्लस डिस्प्ले के साथ मिलेगी 4000mAh बैटरी, कीमत 7,999 रुपए,"
preprocessed_text = preprocess_text(text_to_preprocess)
print(preprocessed_text)
# Out:
# नोकिया c12 प्लस में छः तीन इंच hd प्लस डिस्प्ले के साथ मिलेगी 4000mah बैटरी कीमत सात नौ सौ  निन्यानवे रुपए

# %%
from IPython.display import display
from tqdm import tqdm  # Import tqdm

# Preprocess all columns of the training dataset
print("Training Dataset (Number of samples: {})".format(train_df.shape[0]))
for col in train_df.columns:
    tqdm.pandas(desc=f"Preprocessing {col}")  # Add tqdm progress bar for each column
    train_df[col] = train_df[col].progress_apply(preprocess_text)
display(train_df.head())

# Preprocess all columns of the test dataset
print("\nTest Dataset (Number of samples: {})".format(test_df.shape[0]))
for col in test_df.columns:
    tqdm.pandas(desc=f"Preprocessing {col}")  # Add tqdm progress bar for each column
    test_df[col] = test_df[col].progress_apply(preprocess_text)
display(test_df.head())
# Out:
# Training Dataset (Number of samples: 8000)
# ...
# Preprocessing Article: 100%|██████████| 8000/8000 [01:08<00:00, 117.52it/s]
#                                              Heading  \
# 0  गला दबाकर हत्या की बॉडी बोरे में भरी लोकल मार्...
# 1  तेलंगाना में अट्ठारह की जान गई जम्मू-कश्मीर मे...
# 2  राजस्थान सरकार बनाएगी कर्ज राहत आयोग कोर्ट के ...
# 3  तीन से सात अगस्त तक कर सकेंगे अप्लाय प्राइस बै...
# 4  डाइनिंग टेबल पर कुकर-कड़ाही न सजाएं चीन के खान...
#
#                                              Summary  \
# 0  kerala minor girl rape case केरल के एर्नाकुलम ...
# 1  इस साल मानसून सीजन में कई राज्यों में भारी तबा...
# 2  चुनावी साल में राजस्थान सरकार किसानों को लुभान...
# 3  non-banking lender sbfc finance s initial publ...
# 4  स्वाद खाने की बुनियाद है लेकिन अगर खाना सुंदर ...
#
#                                              Article
# 0  केरल के एर्नाकुलम जिले में पाँच साल की बच्ची स...
# 1  मानसून सीजन में हुई भारी बारिश ने कई राज्यों म...
# ...

# %%
import matplotlib.pyplot as plt

# Function to plot distribution of data in a column
def plot_distribution(ax, data, title):
    # Split the text using space and get the lengths of resulting tokens
    lengths = [len(token.split()) for token in data]

    # Print tokens and their lengths
    # for token, length in zip(data, lengths):
    #     print(f"Token: {token}, Length: {length}")

    # Plot the distribution
    ax.hist(lengths, bins=20, color='skyblue', edgecolor='black')
    ax.set_title(title)
    ax.set_xlabel('Token Length')
    ax.set_ylabel('Frequency')
    ax.grid(True)

# Create a table of subplots for each column in both datasets
fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(20, 10))

# Plot distribution for each column in the training dataset
for i, col in enumerate(train_df.columns[:3]):  # Plot only first 3 columns for training dataset
    plot_distribution(axs[0, i], train_df[col], title=f"Distribution of {col} in Training Dataset")

# Plot distribution for each column in the test dataset
for i, col in enumerate(test_df.columns[:2]):  # Plot only first 2 columns for test dataset
    plot_distribution(axs[1, i], test_df[col], title=f"Distribution of {col} in Test Dataset")

# Hide the sixth subplot (index 2,2)
axs[1, 2].axis('off')

# Adjust layout and display the plots
plt.subplots_adjust(wspace=0.2, hspace=0.3)  # Adjust spacing between subplots
plt.show()

# %% [markdown]
# # **# **Model 1: BART****

# %%
import torch
from transformers import AutoTokenizer
from transformers import AutoModelForSeq2SeqLM

# %%
bart_checkpoint = "ai4bharat/IndicBART"

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(device)
tokenizer_bart = AutoTokenizer.from_pretrained(bart_checkpoint,
                                               do_lower_case=False,
                                               use_fast=False,
                                               keep_accents=True)

model_bart = AutoModelForSeq2SeqLM.from_pretrained(bart_checkpoint).to(device)
# Out:
# cuda
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/498 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/832 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/1.90M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/221 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/398 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# ...

# %%
bos_id = tokenizer_bart._convert_token_to_id_with_added_voc("<s>")
eos_id = tokenizer_bart._convert_token_to_id_with_added_voc("</s>")
pad_id = tokenizer_bart._convert_token_to_id_with_added_voc("<pad>")

# %%
model_bart = AutoModelForSeq2SeqLM.from_pretrained(bart_checkpoint).to(device)
def generate_summary(article, model):
    inp = tokenizer_bart(article, add_special_tokens=False,
                         truncation=True, return_tensors="pt",
                         padding='max_length', max_length=1024)['input_ids']
    inp = inp.to(device)  # Move input tensor to the desired device

    model_output = model.generate(inp, use_cache=True,
                                  num_beams=4,
                                  max_length=70,
                                  min_length=30,
                                  early_stopping=True,
                                  pad_token_id=pad_id,
                                  bos_token_id=bos_id,
                                  eos_token_id=eos_id,
                                  decoder_start_token_id=tokenizer_bart._convert_token_to_id_with_added_voc("<2en>"))

    decoded_output = tokenizer_bart.decode(model_output[0],
                                           skip_special_tokens=True,
                                           clean_up_tokenization_spaces=False)
    return decoded_output


SystemSummary1 = []
for index, row in tqdm(test_df.iterrows(), total=len(test_df)):
    summary = generate_summary(row['Article'], model_bart)
    SystemSummary1.append(summary)



# def generate_summary(heading, article, model):
#   input_text = f"Heading: {heading} Article: {article}"
#   inp = tokenizer_bart(input_text, add_special_tokens=False,
#              truncation=True, return_tensors="pt",
#              padding='max_length', max_length=1024)['input_ids']
#   inp = inp.to(device) # Move input tensor to the desired device

#   model_output = model.generate(inp, use_cache=True,
#                  num_beams=4,
#                  max_length=70,
#                  min_length=30,
#                  early_stopping=True,
#                  pad_token_id=pad_id,
#                  bos_token_id=bos_id,
#                  eos_token_id=eos_id,
#                  decoder_start_token_id=tokenizer_bart._convert_token_to_id_with_added_voc("<2en>"))

#   decoded_output = tokenizer_bart.decode(model_output[0],
#                       skip_special_tokens=True,
#                       clean_up_tokenization_spaces=False)
#   return decoded_output

# SystemSummary1 = []
# for index, row in tqdm(test_df.iterrows(), total=len(test_df)):
#   heading = row['Heading']
#   article = row['Article']
#   summary= generate_summary(heading, article, model_bart)
#   SystemSummary1.append(summary)
# Out:
# 100%|██████████| 2000/2000 [24:08<00:00,  1.38it/s]

# %%
Summaries1 = pd.DataFrame(list(zip(test_df['Summary'], SystemSummary1)), columns =['GoldSummary', 'BartSummary'])
Summaries1
# Out:
#                                             GoldSummary  \
# 0     उत्तर प्रदेश में भाजपा ने चुनाव के लिए अनुराग ...
# 1     मिजोरम के साथ लगी सीमा पर शांति बहाल होने का उ...
# 2     अरुणाचल प्रदेश के भाजपा सांसद तापिर गाओ ने कहा...
# 3     दिल्ली पुलिस कमिश्नर एसएन श्रीवास्तव sn shriva...
# 4     जम्मू-कश्मीर दौरे के तीसरे दिन अमित शाह आज श्र...
# ...                                                 ...
# 1995  कोरोना की लहर के दौरान पूरे देश में पत्रकारों ...
# 1996  unlock चार guidelines देश अभी भी कोरोना के संक...
# 1997  स्कूल में एडमिशन के लिए अब बच्चों का आधार कार्...
# 1998  राजधानी के अवध शिल्पग्राम में चार सौ  पचास बिस...
# 1999  वायरल पोस्ट और वीडियो में दावा किया जा रहा है ...
#
#                                             BartSummary
# 0     नई दिल्ली भारतीय जनता पार्टी ने अगले साल होने ...
# 1     नयी दिल्ली मिजोरम के साथ लगी सीमा पर शांति बहा...
# 2     अरुणाचल प्रदेश के भाजपा सांसद तापिर गाओ ने कहा...
# 3     नई दिल्ली दिल्ली पुलिस कमिश्नर एसएन श्रीवास्तव...
# ...

# %%
from rouge_score import rouge_scorer

# Convert Series to list of strings
bart_summaries = Summaries1['BartSummary'].tolist()
gold_summaries = Summaries1['GoldSummary'].tolist()

# Join the list of strings into a single string
bart_summaries_text = " ".join(bart_summaries)
gold_summaries_text = " ".join(gold_summaries)

scorer = rouge_scorer.RougeScorer(['rouge4', 'rouge2', 'rouge1'], use_stemmer=True)

scores = scorer.score(bart_summaries_text, gold_summaries_text)

rouge4_fscore = scores['rouge4'].fmeasure
rouge2_fscore = scores['rouge2'].fmeasure
rouge1_fscore = scores['rouge1'].fmeasure

print("ROUGE-4 F-score:", rouge4_fscore)
print("ROUGE-2 F-score:", rouge2_fscore)
print("ROUGE-1 F-score:", rouge1_fscore)
# Out:
# ROUGE-4 F-score: 0.09140108238123872
# ROUGE-2 F-score: 0.25554889022195565
# ROUGE-1 F-score: 0.5056920311563811

# %%
from bert_score import score

# Convert Series to list of strings
bart_summaries = Summaries1['BartSummary'].tolist()
gold_summaries = Summaries1['GoldSummary'].tolist()

# Calculate BERTScore
P, R, F1 = score(cands=bart_summaries, refs=gold_summaries, lang='hi', model_type='bert-base-multilingual-cased')

# Print BERTScore
print("BERTScore Precision:", P.mean().item())
print("BERTScore Recall:", R.mean().item())
print("BERTScore F1:", F1.mean().item())
# Out:
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/714M [00:00<?, ?B/s]
# BERTScore Precision: 0.7747821807861328
# BERTScore Recall: 0.8306447863578796
# BERTScore F1: 0.8011037707328796

# %%
from torch.utils.data import Dataset
# class CustomSummarizationDataset(Dataset):
#     def __init__(self, data_df, tokenizer, max_source_length=512, max_target_length=128):
#         self.data_df = data_df
#         self.tokenizer = tokenizer
#         self.max_source_length = max_source_length
#         self.max_target_length = max_target_length

#     def __len__(self):
#         return len(self.data_df)

#     def __getitem__(self, idx):
#         article = str(self.data_df.iloc[idx]['Article'])
#         summary = str(self.data_df.iloc[idx]['Summary'])

#         # Tokenize article and summary
#         encoding = self.tokenizer(article, truncation=True, max_length=self.max_source_length, padding="max_length", return_tensors="pt")
#         label_encoding = self.tokenizer(summary, truncation=True, max_length=self.max_target_length, padding="max_length", return_tensors="pt")
# #         print(label_encoding)
#         # Remove unnecessary keys from label_encoding
#         label_encoding = {k: v.squeeze(0) for k, v in label_encoding.items()}

#         return {
#             "input_ids": encoding["input_ids"].squeeze(0),
#             "attention_mask": encoding["attention_mask"].squeeze(0),
#             "labels": label_encoding["input_ids"]
#         }

# %%
class CustomSummarizationDataset(Dataset):
    def __init__(self, data_df, tokenizer, max_source_length=512, max_target_length=128):
        self.data_df = data_df
        self.tokenizer = tokenizer
        self.max_source_length = max_source_length
        self.max_target_length = max_target_length

    def __len__(self):
        return len(self.data_df)

    def __getitem__(self, idx):
        heading = str(self.data_df.iloc[idx]['Heading'])
        article = str(self.data_df.iloc[idx]['Article'])
        summary = str(self.data_df.iloc[idx]['Summary'])

        # Concatenate heading and article with a separator
        input_text = f"Heading: {heading} Article: {article}"

        # Tokenize input_text and summary
        encoding = self.tokenizer(input_text, truncation=True, max_length=self.max_source_length, padding="max_length", return_tensors="pt")
        label_encoding = self.tokenizer(summary, truncation=True, max_length=self.max_target_length, padding="max_length", return_tensors="pt")

        #Remove unnecessary keys from label_encoding
        label_encoding = {k: v.squeeze(0) for k, v in label_encoding.items()}

        return {
            "input_ids": encoding["input_ids"].squeeze(0),
            "attention_mask": encoding["attention_mask"].squeeze(0),
            "labels": label_encoding["input_ids"]
        }

# %%
train_dataset = CustomSummarizationDataset(train_df, tokenizer_bart)
test_dataset = CustomSummarizationDataset(test_df, tokenizer_bart)

# %%
from transformers import TrainingArguments, Trainer

print(device)
training_args = TrainingArguments(
    output_dir='./results',  # Output directory
    num_train_epochs=3,  # Number of training epochs
    per_device_train_batch_size=4,  # Batch size per device during training
    per_device_eval_batch_size=4,  # Batch size for evaluation
    warmup_steps=100,  # Number of warmup steps for learning rate scheduler
    weight_decay=0.01,  # Strength of weight decay
    logging_dir='./logs',  # Directory for storing logs
)

trainer = Trainer(
    model=model_bart,  # The instantiated 🤗 Transformers model to be trained
    args=training_args,  # Training arguments
    train_dataset=train_dataset,  # Training dataset
    eval_dataset=test_dataset,  # Evaluation dataset
)

# Fine-tune the model
trainer.train()
# Out:
# cuda
#     <div>
#
#       <progress value='3501' max='6000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3501/6000 40:05 < 28:38, 1.45 it/s, Epoch 1.75/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>3.786400</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>1.067800</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.967000</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.961100</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.898000</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.873800</td>
#     </tr>
#   </tbody>
# </table><p>
# ...

# %%
import matplotlib.pyplot as plt

# Your training loss data
steps = [500, 1000, 1500, 2000, 2500, 3000]
loss = [3.7864, 1.0678, 0.967, 0.9611, 0.898, 0.8738]

# Plotting
plt.plot(steps, loss, marker='o', linestyle='-')
plt.title('Training Loss vs. Steps')
plt.xlabel('Steps')
plt.ylabel('Training Loss')
plt.grid(True)
plt.show()

# %%
model_output_dir = "/content/fine_tuned_model"
model_bart.save_pretrained(model_output_dir)
# Out:
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'forced_eos_token_id': 2}

# %%
import zipfile
import os

# Specify the folder path you want to zip
folder_path = "/content/fine_tuned_model"

# Specify the zip file name and path
zip_file_name = "fine_tuned_model_zip.zip"
zip_file_path = "/content/" + zip_file_name

# Create a zip archive of the folder
with zipfile.ZipFile(zip_file_path, 'w', zipfile.ZIP_DEFLATED) as zipf:
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            zipf.write(os.path.join(root, file), os.path.relpath(os.path.join(root, file), os.path.join(folder_path, '..')))


from IPython.display import FileLink

# Download the zip file
FileLink(zip_file_path)
# Out:
# /content/fine_tuned_model_zip.zip

# %%
def generate_summary(article, model):
    inp = tokenizer_bart(article, add_special_tokens=False,
                         truncation=True, return_tensors="pt",
                         padding='max_length', max_length=1024)['input_ids']
    inp = inp.to(device)  # Move input tensor to the desired device

    model_output = model.generate(inp, use_cache=True,
                                  num_beams=4,
                                  max_length=70,
                                  min_length=30,
                                  early_stopping=True,
                                  pad_token_id=pad_id,
                                  bos_token_id=bos_id,
                                  eos_token_id=eos_id,
                                  decoder_start_token_id=tokenizer_bart._convert_token_to_id_with_added_voc("<2en>"))

    decoded_output = tokenizer_bart.decode(model_output[0],
                                           skip_special_tokens=True,
                                           clean_up_tokenization_spaces=False)
    return decoded_output

# %%
model_name = "/content/fine_tuned_model"
model = AutoModelForSeq2SeqLM.from_pretrained(model_name).to(device)


# Apply summarization to each row in the DataFrame
SystemSummary = []
for index, row in tqdm(test_df.iterrows(), total=len(test_df)):
    summary = generate_summary(row['Article'], model)
    SystemSummary.append(summary)

# %%
Summaries = pd.DataFrame(list(zip(test_df['Summary'], SystemSummary)), columns =['GoldSummary', 'BartSummary'])
Summaries
# Out:
#                                           GoldSummary  \
# 0   उत्तर प्रदेश में भाजपा ने चुनाव के लिए अनुराग ...
# 1   मिजोरम के साथ लगी सीमा पर शांति बहाल होने का उ...
# 2   अरुणाचल प्रदेश के भाजपा सांसद तापिर गाओ ने कहा...
# 3   दिल्ली पुलिस कमिश्नर एसएन श्रीवास्तव sn shriva...
# 4   जम्मू-कश्मीर दौरे के तीसरे दिन अमित शाह आज श्र...
# 5   संसद हंगामे के लिए नहीं होती है बल्कि यह चर्चा...
# 6   आधार कार्ड एक बेहद ही जरुरी डॉक्यूमेंट हो गया ...
# 7   मौसम विभाग ने राजधानी और आसपास के इलाकों में अ...
# 8   प्रधानमंत्री नरेंद्र मोदी ने कहा कि खेती को खु...
# 9   हरियाणा में शुक्रवार को कोरोना वायरस के दो छः ...
# 10  भाजपा विधायक दल के नेता इस तटीय राज्य के अगले ...
# 11  प्रधानमंत्री नरेन्द्र मोदी ग्यारह दिसंबर दो हज...
# 12  सात फरवरी को आयी आपदा में यहां पर लखीमपुर खीरी...
# 13  उत्तर रेलवे ने यात्रियों की बढ़ती संख्या को दे...
# 14  भोपाल के इंडियन इंस्टीट्यूट ऑफ साइंस एजुकेशन ए...
# 15  उत्तर प्रदेश के मुख्यमंत्री योगी आदित्यनाथ ने ...
# ...

# %%
# !pip install rouge_score
# !pip install bert_score
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 824.6 kB/s eta 0:00:00--:--
# ...

# %%
from rouge_score import rouge_scorer

# Convert Series to list of strings
bart_summaries = Summaries['BartSummary'].tolist()
gold_summaries = Summaries['GoldSummary'].tolist()

# Join the list of strings into a single string
bart_summaries_text = " ".join(bart_summaries)
gold_summaries_text = " ".join(gold_summaries)

scorer = rouge_scorer.RougeScorer(['rouge4', 'rouge2', 'rouge1'], use_stemmer=True)

scores = scorer.score(bart_summaries_text, gold_summaries_text)

rouge4_fscore = scores['rouge4'].fmeasure
rouge2_fscore = scores['rouge2'].fmeasure
rouge1_fscore = scores['rouge1'].fmeasure

print("ROUGE-4 F-score:", rouge4_fscore)
print("ROUGE-2 F-score:", rouge2_fscore)
print("ROUGE-1 F-score:", rouge1_fscore)

# %%
from bert_score import score

# Convert Series to list of strings
bart_summaries = Summaries['BartSummary'].tolist()
gold_summaries = Summaries['GoldSummary'].tolist()

# Calculate BERTScore
P, R, F1 = score(cands=bart_summaries, refs=gold_summaries, lang='hi', model_type='bert-base-multilingual-cased')

# Print BERTScore
print("BERTScore Precision:", P.mean().item())
print("BERTScore Recall:", R.mean().item())
print("BERTScore F1:", F1.mean().item())

# %%
from IPython.display import display
from tqdm import tqdm  # Import tqdm

# Preprocess all columns of the training dataset
print("Training Dataset (Number of samples: {})".format(train_df.shape[0]))
for col in train_df.columns:
    tqdm.pandas(desc=f"Preprocessing {col}")  # Add tqdm progress bar for each column
    train_df[col] = train_df[col].progress_apply(preprocess_text)
# Add _START_ and _END_ tokens to the 'Summary' column in train_df
# train_df['Summary'] = '_START_ ' + train_df['Summary'] + ' _END_'

display(train_df.head())

# Preprocess all columns of the test dfset
print("\nTest dfset (Number of samples: {})".format(test_df.shape[0]))
for col in test_df.columns:
    tqdm.pandas(desc=f"Preprocessing {col}")  # Add tqdm progress bar for each column
    test_df[col] = test_df[col].progress_apply(preprocess_text)
# Add _START_ and _END_ tokens to the 'Summary' column in test_df
# test_df['Summary'] = '_START_ ' + test_df['Summary'] + ' _END_'
display(test_df.head())

# %%
import matplotlib.pyplot as plt

# Data
steps = [500, 1000, 1500, 2000, 2500, 3000, 3500, 4000]
training_loss = [0.3425, 0.3114, 0.2976, 0.3026, 0.2767, 0.2738, 0.2646, 0.272]
validation_loss = [0.293737, 0.287693, 0.283664, 0.282422, 0.279961, 0.277298, 0.275109, 0.278584]

# Plot
plt.figure(figsize=(10, 6))
plt.plot(steps, training_loss, label='Training Loss', marker='o')
plt.plot(steps, validation_loss, label='Validation Loss', marker='o')
plt.title('Loss vs. Steps')
plt.xlabel('Steps')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # **End**
